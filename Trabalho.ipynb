# %% [markdown]
# ## Trabalho: Definição de Dataset, Limpeza e Análise dos Dados
#
# **Aluno: Fabio Kishino**
#
# ### Descrição do dataset
#
# O dataset escolhido para o presente trabalho é referente ao [portal da transparência do estado do Paraná](https://www.transparencia.pr.gov.br/pte/pessoal/servidores/poderexecutivo/remuneracao?windowId=fa9) e ele possui informações sobre remuneração, cargo e local de trabalho dos servidores civis e militares - Ativos, Aposentados, da Reserva e Reformados, Pensionistas e beneficiários de Pensões Especiais, e de ex-Servidores - do Poder Executivo do Estado do Paraná, estão aqui. A publicação atende as normas que tratam da transparência da Administração Pública: [Lei Federal 12.527/2011](http://www.planalto.gov.br/ccivil_03/_ato2011-2014/2011/lei/l12527.htm), [Lei Estadual 16.595/2010](http://www.legislacao.pr.gov.br/legislacao/pesquisarAto.do?action=exibir&codAto=56502&indice=1&totalRegistros=1) e [Decreto Estadual 10.285/2014](http://www.legislacao.pr.gov.br/legislacao/pesquisarAto.do?action=exibir&codAto=114209&indice=1&totalRegistros=1).
#
#
# Ele possui um total de 871713 registros e contém as seguintes colunas: cod_vinculo, nome, sigla, instituicao, lotacao, municipio, cargo, dt_inicio, dt_fim, regime, quadro_funcional, quadro_funcional_desc, tipo_cargo, situacao, ult_remu_bruta, genero, ano_nasc e atualizado.
#
# ### Perguntas iniciais
#
# 1. Quais são os cargos mais frequentes dos servidores ativos no Paraná?
# 2. Qual a média salarial para cada um dos 5 municípios do estado do Paraná que possuem maior concentração de servidores públicos?
# 3. Qual a diferença da média salarial entre homens e mulheres em Curitiba?
# 4. Quais são os cargos que mais recebem e quais são os que menos recebem?
# 5. Dos cargos que mais recebem, qual a idade média desses servidores?
# 6. Qual a distribuição da idade dos servidores por gênero?

# %% [markdown]
# ## Limpeza do dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('TB_RH.csv', sep=';')
df.columns = df.columns.str.upper()

df.head()
# Out:
#    COD_VINCULO                    NOME SIGLA  \
# 0       285734             VIVIAN THES  SEED
# 1       243425           VIVIAN XAVIER  SEED
# 2       599094     VIVIAN XAVIER BUENO  SEJU
# 3       112011  VIVIAN ZUQUINALI FELIX  SEED
# 4       446430  VIVIAN ZUQUINALI FELIX  SEED
#
#                                          INSTITUICAO  \
# 0                             SECRETARIA DA EDUCAÇÃO
# 1                             SECRETARIA DA EDUCAÇÃO
# 2  SECRETARIA DA JUSTIÇA, TRABALHO E DIREITOS HUM...
# 3                             SECRETARIA DA EDUCAÇÃO
# 4                             SECRETARIA DA EDUCAÇÃO
#
#                          LOTACAO             MUNICIPIO  \
# 0   E E DJALMA JOHNSSON - E FUND              CURITIBA
# 1  ESC EST PROF JOSE G DO AMARAL          PONTA GROSSA
# 2  DEPARTAMENTO DO TRABALHO - DT              CURITIBA
# 3  ESC EST GUARANI ESTRAT - 1 GR      NOVA LARANJEIRAS
# 4  E E IRACI SALETE STROZAKI E F  RIO BONITO DO IGUACU
#
#                            CARGO   DT_INICIO      DT_FIM       REGIME  \
# 0                      PROFESSOR  2012-02-01         NaN  ESTATUTÁRIO
# 1                      PROFESSOR  2012-04-02         NaN  ESTATUTÁRIO
# 2    PROFISSIONAL DE NÍVEL MÉDIO  2018-02-20  2018-12-31   TEMPORÁRIO
# 3  DOCENTE POR PRAZO DETERMINADO  2012-02-01  2013-12-31   TEMPORÁRIO
# 4  DOCENTE POR PRAZO DETERMINADO  2014-02-03  2014-12-31   TEMPORÁRIO
#
#   QUADRO_FUNCIONAL QUADRO_FUNCIONAL_DESC TIPO_CARGO   SITUACAO  \
# 0              QPM            MAGISTÉRIO    EFETIVO      ATIVO
# 1              QPM            MAGISTÉRIO    EFETIVO      ATIVO
# 2             CRES           TEMPORÁRIOS       ****  DESLIGADO
# 3             CRES           TEMPORÁRIOS       ****  DESLIGADO
# 4             CRES           TEMPORÁRIOS       ****  DESLIGADO
#
#    ULT_REMU_BRUTA GENERO  ANO_NASC  ATUALIZADO
# 0         9178.01      F    1977.0  2025-07-01
# 1         9626.30      F    1976.0  2025-07-01
# 2            0.00      F    1983.0  2019-01-01
# 3            0.00      F    1980.0  2016-07-27
# 4            0.00      F    1980.0  2016-07-27

# %%
# Renomeando o nome das colunas para facilitar interpretação
df = df.rename(columns={
  'DT_INICIO': 'DATA_INICIO',
  'DT_FIM': 'DATA_FIM',
  'ULT_REMU_BRUTA': 'ULTIMA_REMUNERACAO_BRUTA',
  'ANO_NASC': 'ANO_NASCIMENTO',
})

# Filtrar o dataset para incluir apenas servidores em situação ATIVO
pd.unique(df['SITUACAO'])
df_ativos = df[df['SITUACAO'] == 'ATIVO']

df_ativos
# Out:
#         COD_VINCULO                              NOME SIGLA  \
# 0            285734                       VIVIAN THES  SEED
# 1            243425                     VIVIAN XAVIER  SEED
# 11           894417            VIVIAN ZUQUINALI FELIX  SEED
# 13            25997          VIVIANA ALBINO VORAKOSKI  SEED
# 14           301536          VIVIANA ALBINO VORAKOSKI  SEED
# ...             ...                               ...   ...
# 871693       896687            VIVIAN ROCHA RODRIGUES  SEED
# 871695       191609            VIVIAN SCHUG LOCATELLI  SEED
# 871699        82331               VIVIAN SIMONE URBAN  SEED
# 871700       182652               VIVIAN SIMONE URBAN  SEED
# 871711        96746  VIVIAN THAIS BALDESSAR MENEGAZZO  SEAB
#
#                                       INSTITUICAO  \
# 0                          SECRETARIA DA EDUCAÇÃO
# 1                          SECRETARIA DA EDUCAÇÃO
# 11                         SECRETARIA DA EDUCAÇÃO
# 13                         SECRETARIA DA EDUCAÇÃO
# 14                         SECRETARIA DA EDUCAÇÃO
# ...                                           ...
# 871693                     SECRETARIA DA EDUCAÇÃO
# 871695                     SECRETARIA DA EDUCAÇÃO
# 871699                     SECRETARIA DA EDUCAÇÃO
# 871700                     SECRETARIA DA EDUCAÇÃO
# 871711  SECRETARIA DA AGRICULTURA E ABASTECIMENTO
#
#                                LOTACAO         MUNICIPIO  \
# 0         E E DJALMA JOHNSSON - E FUND          CURITIBA
# 1        ESC EST PROF JOSE G DO AMARAL      PONTA GROSSA
# 11      COL.EST.LUDOVICA SAFRAIDER 1/2    PORTO BARREIRO
# 13             COL EST SAGRADA FAMILIA       CAMPO LARGO
# 14                  ESC EST JOAO XXIII       CAMPO LARGO
# ...                                ...               ...
# 871693             COL EST SOUZA NAVES          ROLANDIA
# 871695          COL.EST.LEONILDA PAPEN          MERCEDES
# 871699         ESC EST VICTOR BUSSMANN  CAMPO DO TENENTE
# 871700         ESC EST VICTOR BUSSMANN  CAMPO DO TENENTE
# 871711             NR-UNIAO DA VITORIA  UNIAO DA VITORIA
#
#                                 CARGO DATA_INICIO DATA_FIM       REGIME  \
# 0                           PROFESSOR  2012-02-01      NaN  ESTATUTÁRIO
# 1                           PROFESSOR  2012-04-02      NaN  ESTATUTÁRIO
# 11      DOCENTE POR PRAZO DETERMINADO  2025-02-03      NaN   TEMPORÁRIO
# 13                          PROFESSOR  2012-04-02      NaN  ESTATUTÁRIO
# 14                          PROFESSOR  2012-02-01      NaN  ESTATUTÁRIO
# ...                               ...         ...      ...          ...
# 871693  DOCENTE POR PRAZO DETERMINADO  2025-02-03      NaN   TEMPORÁRIO
# 871695                      PROFESSOR  2005-02-24      NaN  ESTATUTÁRIO
# 871699                      PROFESSOR  2003-12-01      NaN  ESTATUTÁRIO
# 871700                      PROFESSOR  2003-11-30      NaN  ESTATUTÁRIO
# 871711             AGENTE DE EXECUÇÃO  2009-01-05      NaN  ESTATUTÁRIO
#
#        QUADRO_FUNCIONAL QUADRO_FUNCIONAL_DESC TIPO_CARGO SITUACAO  \
# 0                   QPM            MAGISTÉRIO    EFETIVO    ATIVO
# 1                   QPM            MAGISTÉRIO    EFETIVO    ATIVO
# 11                 CRES           TEMPORÁRIOS       ****    ATIVO
# 13                  QPM            MAGISTÉRIO    EFETIVO    ATIVO
# 14                  QPM            MAGISTÉRIO    EFETIVO    ATIVO
# ...                 ...                   ...        ...      ...
# 871693             CRES           TEMPORÁRIOS       ****    ATIVO
# 871695              QPM            MAGISTÉRIO    EFETIVO    ATIVO
# 871699              QPM            MAGISTÉRIO    EFETIVO    ATIVO
# 871700              QPM            MAGISTÉRIO    EFETIVO    ATIVO
# 871711             QPPE          QUADRO GERAL    EFETIVO    ATIVO
#
#         ULTIMA_REMUNERACAO_BRUTA GENERO  ANO_NASCIMENTO  ATUALIZADO
# 0                        9178.01      F          1977.0  2025-07-01
# 1                        9626.30      F          1976.0  2025-07-01
# 11                       2617.23      F          1980.0  2025-07-01
# 13                       4303.13      F          1976.0  2025-07-01
# 14                       8080.60      F          1976.0  2025-07-01
# ...                          ...    ...             ...         ...
# 871693                   1416.50      F          1981.0  2025-07-01
# 871695                   4984.64      F          1975.0  2025-07-01
# 871699                   8275.48      F          1970.0  2025-07-01
# 871700                  10900.04      F          1970.0  2025-07-01
# 871711                   9672.94      F          1979.0  2025-07-01
#
# [159785 rows x 18 columns]

# %%
# Verificando os tipos de dados
df_ativos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159785 entries, 0 to 871711
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   COD_VINCULO               159785 non-null  int64
#  1   NOME                      159785 non-null  object
#  2   SIGLA                     159785 non-null  object
#  3   INSTITUICAO               159785 non-null  object
#  4   LOTACAO                   159781 non-null  object
#  5   MUNICIPIO                 159785 non-null  object
#  6   CARGO                     159785 non-null  object
#  7   DATA_INICIO               159785 non-null  object
#  8   DATA_FIM                  0 non-null       object
#  9   REGIME                    159785 non-null  object
#  10  QUADRO_FUNCIONAL          159785 non-null  object
#  11  QUADRO_FUNCIONAL_DESC     159785 non-null  object
#  12  TIPO_CARGO                159785 non-null  object
#  13  SITUACAO                  159785 non-null  object
#  14  ULTIMA_REMUNERACAO_BRUTA  159785 non-null  float64
#  15  GENERO                    159785 non-null  object
#  16  ANO_NASCIMENTO            159785 non-null  float64
#  17  ATUALIZADO                159785 non-null  object
# dtypes: float64(2), int64(1), object(15)
# memory usage: 23.2+ MB

# %%
# Formatando a coluna DATA_INICIO para obter o ano de início do servidor
df_ativos.loc[:, 'ANO_INICIO'] = pd.to_datetime(df_ativos['DATA_INICIO']).dt.year
# Out:
# /var/folders/np/801w6bmj0d78pf0s_9hln43h0000gn/T/ipykernel_1660/3334978518.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ativos.loc[:, 'ANO_INICIO'] = pd.to_datetime(df_ativos['DATA_INICIO']).dt.year

# %%
## Removendo outliers
# Verificando a distribuição da coluna ULTIMA_REMUNERACAO_BRUTA
df_ativos['ULTIMA_REMUNERACAO_BRUTA'].hist(bins=100, grid=False)
plt.title("Distribuição da Remuneração Bruta")
plt.xlabel("Remuneração")
plt.ylabel("Quantidade de Servidores")
plt.show()

q3 = df_ativos['ULTIMA_REMUNERACAO_BRUTA'].quantile(0.03)
q97 = df_ativos['ULTIMA_REMUNERACAO_BRUTA'].quantile(0.97)

df_ativos_filtrado = df_ativos[(df_ativos['ULTIMA_REMUNERACAO_BRUTA'] >= q3) & (df_ativos['ULTIMA_REMUNERACAO_BRUTA'] <= q97)]

df_ativos_filtrado['ULTIMA_REMUNERACAO_BRUTA'].hist(bins=100, color='green', grid=False)
plt.title("Distribuição da Remuneração Bruta após remoção de outliers")
plt.xlabel("Remuneração")
plt.ylabel("Quantidade de Servidores")
plt.show()

df_ativos_filtrado.describe()
# Out:
#          COD_VINCULO  ULTIMA_REMUNERACAO_BRUTA  ANO_NASCIMENTO     ANO_INICIO
# count  150197.000000             150197.000000   150197.000000  150197.000000
# mean   469490.579452               8235.927600     1978.044615    2012.942968
# std    311518.535370               4308.443833       10.811676       9.622557
# min      2349.000000               2030.600000     1932.000000    1970.000000
# 25%    195605.000000               5255.270000     1970.000000    2006.000000
# 50%    402906.000000               7432.690000     1978.000000    2012.000000
# 75%    856703.000000               9631.790000     1986.000000    2024.000000
# max    915367.000000              26592.070000     2007.000000    2025.000000

# %% [markdown]
# # Análise Exploratória 📊

# %% [markdown]
# ## 1. Quais são os cargos mais frequentes dos servidores ativos no Paraná?

# %%
df_ativos_filtrado.groupby('CARGO').size().sort_values(ascending=False).head(20)
# Percebe-se que existem cargos que não foram corretamente digitados (****)

# Mostrar os registros com cargos incorretos juntamente com a coluna QUADRO_FUNCIONAL_DESC
df_sem_cargos = df_ativos_filtrado[df_ativos_filtrado['CARGO'] == '****'][['CARGO', 'QUADRO_FUNCIONAL_DESC']]
df_sem_cargos['QUADRO_FUNCIONAL_DESC'].unique()
# Out:
# array(['POLÍCIA MILITAR', 'POLÍCIA CIVIL'], dtype=object)

# %%
# Percebe-se que o quadro funcional sempre corresponde à cargos da Policia Militar e Civil, mas não é possível identificar qual é o cargo exatamente e outros valores de outras colunas.
# Por isso, será necessário descarta-los.
df_ativos_filtrado = df_ativos_filtrado[df_ativos_filtrado['CARGO'] != '****'] 

df_top_cargos = df_ativos_filtrado.groupby('CARGO').size().sort_values(ascending=False).head(10)
df_top_cargos
# Out:
# CARGO
# PROFESSOR                         48090
# DOCENTE POR PRAZO DETERMINADO     28007
# AGENTE EDUCACIONAL II              7313
# AGENTE EDUCACIONAL I               6761
# PROFESSOR DE ENSINO SUPERIOR       4486
# CARGO COMISSIONADO EXECUTIVO       3712
# POLICIAL PENAL                     2542
# PROMOTOR DE SAUDE EXECUCAO         2524
# AGENTE PROFISSIONAL                1937
# PROMOTOR DE SAUDE PROFISSIONAL     1869
# dtype: int64

# %%
df_top_cargos = df_top_cargos.sort_values(ascending=True)

# Gráfico de barras horizontais para os 10 cargos com mais servidores ativos
for index, value in enumerate(df_top_cargos.values):
    plt.text(value, index, str(value))
    plt.xlim(0, df_top_cargos.values.max() * 1.1)

plt.barh(df_top_cargos.index, df_top_cargos.values, color='green')
plt.xlabel('Quantidade de Servidores')
plt.title('Top 10 Cargos com mais servidores ativos')
plt.show()

# %% [markdown]
# ## 2. Qual a média salarial para cada um dos 5 municípios do estado do Paraná que possuem a maior concentração de servidores públicos?

# %%
top_municipio = pd.DataFrame(df_ativos_filtrado.groupby('MUNICIPIO').size().sort_values(ascending=False).head(5))
print("Top 5 municípios com mais servidores ativos:")
print(top_municipio)
top_municipio.columns = ['QUANTIDADE_SERVIDORES']

for index, value in enumerate(top_municipio.values):
    plt.text(value, index, str(value))
    plt.xlim(0, top_municipio.values.max() * 1.1)

plt.barh(top_municipio.index, top_municipio['QUANTIDADE_SERVIDORES'], color='green')
plt.xlabel('Quantidade de Servidores')
plt.title('Top 5 Municípios com mais servidores ativos')
plt.show()
# Out:
# Top 5 municípios com mais servidores ativos:
#                   0
# MUNICIPIO
# CURITIBA      24419
# LONDRINA       9047
# MARINGA        6175
# CASCAVEL       5371
# PONTA GROSSA   4620

# %%
plt.pie(top_municipio['QUANTIDADE_SERVIDORES'], labels=top_municipio.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribuição da quantidade de Servidores Ativos nos Municípios com maior concentração')
plt.show()

# %%
# Calcular a média das remunerações brutas dos servidores ativos nos município com maior concentração de servidores
top_municipio_remuneracao = pd.DataFrame(round(df_ativos_filtrado.groupby('MUNICIPIO')['ULTIMA_REMUNERACAO_BRUTA'].mean().sort_values(ascending=False),2))
print("\nMédia das remunerações dos servidores ativos por município:")
print(top_municipio_remuneracao)
# Out:
# Média das remunerações dos servidores ativos por município:
#                          ULTIMA_REMUNERACAO_BRUTA
# MUNICIPIO
# MARINGA                                  10923.79
# LONDRINA                                  9930.13
# MARECHAL CANDIDO RONDON                   9551.45
# PONTA GROSSA                              9156.35
# IRATI                                     8930.75
# ...                                           ...
# MERCEDES                                  5703.79
# ESPERANCA NOVA                            5684.94
# DIAMANTE D OESTE                          5587.47
# PORTO AMAZONAS                            5557.14
# PORTO BARREIRO                            5424.04
#
# [400 rows x 1 columns]

# %%
# Obter a média salarial para os 5 municípios com a maior concentração de servidores públicos
df_top_municipio_remuneracao = pd.merge(top_municipio, top_municipio_remuneracao, how='inner', on='MUNICIPIO')
df_top_municipio_remuneracao.columns = ['QUANTIDADE_SERVIDORES', 'MEDIA_REMUNERACAO_BRUTA']

display(df_top_municipio_remuneracao)
# Out:
#               QUANTIDADE_SERVIDORES  MEDIA_REMUNERACAO_BRUTA
# MUNICIPIO
# CURITIBA                      24419                  8640.16
# LONDRINA                       9047                  9930.13
# MARINGA                        6175                 10923.79
# CASCAVEL                       5371                  8863.59
# PONTA GROSSA                   4620                  9156.35

# %% [markdown]
# ## 3. Qual a diferença da média salarial entre homens e mulheres em Curitiba?

# %%
df_remuneracao_genero_cwb = df_ativos_filtrado[df_ativos_filtrado['MUNICIPIO'] == 'CURITIBA']

df_remuneracao_genero_cwb = df_remuneracao_genero_cwb.groupby('GENERO')['ULTIMA_REMUNERACAO_BRUTA'].mean().round(2)

# Gráfico de barras para comparar a média salarial entre homens e mulheres
for i, v in enumerate(df_remuneracao_genero_cwb.values):
  plt.text(i, v, f'R${v:.2f}', ha='center', va='bottom')
df_remuneracao_genero_cwb.plot(kind='bar', color=['magenta', 'blue'], title='Média Salarial de Curitiba por gênero', xlabel='Gênero', ylabel='Média Salarial Bruta')
# Out:
# <Axes: title={'center': 'Média Salarial de Curitiba por gênero'}, xlabel='Gênero', ylabel='Média Salarial Bruta'>

# %% [markdown]
# ## 4. Quais são os cargos que mais recebem e quais são os que menos recebem?

# %%
# As 5 médias salariais mais altas e seus respectivos cargos
df_cargo_remuneracao_alto = df_ativos_filtrado.groupby('CARGO')['ULTIMA_REMUNERACAO_BRUTA'].mean().round(2)
df_cargo_remuneracao_alto = df_cargo_remuneracao_alto.sort_values(ascending=False).head(5)
df_cargo_remuneracao_alto
# Out:
# CARGO
# ANALISTA ADMINIST. PL                  26569.83
# ASSESSOR DE COMUNICACAO SOCIAL         26522.00
# ASSESSOR DE RELACOES INSTITUCIONAIS    26372.00
# CONTROLADOR GERAL                      26372.00
# COORDENADOR ADMINISTRATIVO             26372.00
# Name: ULTIMA_REMUNERACAO_BRUTA, dtype: float64

# %%
# As 5 médias salariais mais baixas e seus respectivos cargos
df_cargo_remuneracao_baixo = df_ativos_filtrado.groupby('CARGO')['ULTIMA_REMUNERACAO_BRUTA'].mean().round(2)
df_cargo_remuneracao_baixo = df_cargo_remuneracao_baixo.sort_values(ascending=True).head(5)
df_cargo_remuneracao_baixo
# Out:
# CARGO
# DIRETORA DE CENA                2134.88
# LOCUTOR                         2329.63
# FUNÇÃO ACADÊMICA DAS IEES FA    2464.66
# AUXILIAR ADMINISTRATIVO         2697.83
# LOCUTORA                        2761.83
# Name: ULTIMA_REMUNERACAO_BRUTA, dtype: float64

# %% [markdown]
# ## 5. Dos cargos que mais recebem, qual a idade média desses servidores?

# %%
from datetime import datetime

# Calcular a idade dos servidores
current_year = datetime.now().year
df_ativos_filtrado['IDADE'] = current_year - df_ativos_filtrado['ANO_NASCIMENTO']
df_ativos_filtrado.head()
# Out:
#     COD_VINCULO                      NOME SIGLA             INSTITUICAO  \
# 0        285734               VIVIAN THES  SEED  SECRETARIA DA EDUCAÇÃO
# 1        243425             VIVIAN XAVIER  SEED  SECRETARIA DA EDUCAÇÃO
# 11       894417    VIVIAN ZUQUINALI FELIX  SEED  SECRETARIA DA EDUCAÇÃO
# 13        25997  VIVIANA ALBINO VORAKOSKI  SEED  SECRETARIA DA EDUCAÇÃO
# 14       301536  VIVIANA ALBINO VORAKOSKI  SEED  SECRETARIA DA EDUCAÇÃO
#
#                            LOTACAO       MUNICIPIO  \
# 0     E E DJALMA JOHNSSON - E FUND        CURITIBA
# 1    ESC EST PROF JOSE G DO AMARAL    PONTA GROSSA
# 11  COL.EST.LUDOVICA SAFRAIDER 1/2  PORTO BARREIRO
# 13         COL EST SAGRADA FAMILIA     CAMPO LARGO
# 14              ESC EST JOAO XXIII     CAMPO LARGO
#
#                             CARGO DATA_INICIO DATA_FIM       REGIME  \
# 0                       PROFESSOR  2012-02-01      NaN  ESTATUTÁRIO
# 1                       PROFESSOR  2012-04-02      NaN  ESTATUTÁRIO
# 11  DOCENTE POR PRAZO DETERMINADO  2025-02-03      NaN   TEMPORÁRIO
# 13                      PROFESSOR  2012-04-02      NaN  ESTATUTÁRIO
# 14                      PROFESSOR  2012-02-01      NaN  ESTATUTÁRIO
#
#    QUADRO_FUNCIONAL QUADRO_FUNCIONAL_DESC TIPO_CARGO SITUACAO  \
# 0               QPM            MAGISTÉRIO    EFETIVO    ATIVO
# 1               QPM            MAGISTÉRIO    EFETIVO    ATIVO
# 11             CRES           TEMPORÁRIOS       ****    ATIVO
# 13              QPM            MAGISTÉRIO    EFETIVO    ATIVO
# 14              QPM            MAGISTÉRIO    EFETIVO    ATIVO
#
#     ULTIMA_REMUNERACAO_BRUTA GENERO  ANO_NASCIMENTO  ATUALIZADO  ANO_INICIO  \
# 0                    9178.01      F          1977.0  2025-07-01        2012
# 1                    9626.30      F          1976.0  2025-07-01        2012
# 11                   2617.23      F          1980.0  2025-07-01        2025
# 13                   4303.13      F          1976.0  2025-07-01        2012
# 14                   8080.60      F          1976.0  2025-07-01        2012
#
#     IDADE
# 0    48.0
# 1    49.0
# 11   45.0
# 13   49.0
# 14   49.0

# %%
df_media_idade_cargo = df_ativos_filtrado[['CARGO','IDADE']].groupby('CARGO').mean().sort_values(by='IDADE', ascending=False).astype(int)

df_media_idade_cargo_alta_remuneracao = df_media_idade_cargo.loc[df_cargo_remuneracao_alto.index]
df_media_idade_cargo_alta_remuneracao
# Out:
#                                      IDADE
# CARGO
# ANALISTA ADMINIST. PL                   67
# ASSESSOR DE COMUNICACAO SOCIAL          81
# ASSESSOR DE RELACOES INSTITUCIONAIS     85
# CONTROLADOR GERAL                       29
# COORDENADOR ADMINISTRATIVO              54

# %% [markdown]
# ## 6. Qual a distribuição da idade dos servidores por gênero?

# %%
df_ativos_filtrado.boxplot(column='IDADE', by='GENERO', grid=False)

print("Estatísticas descritivas da idade dos servidores ativos por gênero:")
print("Masculino:")
print(df_ativos_filtrado[df_ativos_filtrado['GENERO'] == 'M']['IDADE'].describe())

print("Feminino:")
print(df_ativos_filtrado[df_ativos_filtrado['GENERO'] == 'F']['IDADE'].describe())
# Out:
# Estatísticas descritivas da idade dos servidores ativos por gênero:
# Masculino:
# count    45317.000000
# mean        47.071099
# std         11.201320
# min         19.000000
# 25%         39.000000
# 50%         47.000000
# 75%         56.000000
# max         93.000000
# Name: IDADE, dtype: float64
# Feminino:
# count    86218.000000
# mean        48.293396
# std         10.609076
# min         18.000000
# 25%         41.000000
# 50%         49.000000
# 75%         56.000000
# max         84.000000
# Name: IDADE, dtype: float64

# %% [markdown]
# ## Modelagem 🔨

# %% [markdown]
# ## Regressão Linear
# Objetivo: Previsão das variáveis que influenciam a Remuneração Bruta

# %%
from statsmodels.formula.api import ols

df_modelo = df_ativos_filtrado.copy()

df_modelo = df_modelo[df_modelo['MUNICIPIO'] == 'CURITIBA']

modelo = ols(formula="ULTIMA_REMUNERACAO_BRUTA ~ IDADE + C(GENERO) + C(CARGO) + C(REGIME) + C(QUADRO_FUNCIONAL_DESC)", data=df_modelo)

response = modelo.fit()

print(response.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     ULTIMA_REMUNERACAO_BRUTA   R-squared:                       0.558
# Model:                                  OLS   Adj. R-squared:                  0.551
# Method:                       Least Squares   F-statistic:                     80.82
# Date:                      Sun, 10 Aug 2025   Prob (F-statistic):               0.00
# Time:                              17:17:42   Log-Likelihood:            -2.3006e+05
# No. Observations:                     24419   AIC:                         4.609e+05
# Df Residuals:                         24043   BIC:                         4.639e+05
# Df Model:                               375
# Covariance Type:                  nonrobust
# ===================================================================================================================================================================
#                                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                        -947.1738   3013.875     -0.314      0.753   -6854.558    4960.211
# C(GENERO)[T.M]                                                                                    127.3819     42.613      2.989      0.003      43.857     210.906
# C(CARGO)[T.1022-DIRETOR DE ADMINISTRAÇÃO E FINANÇAS]                                              2.23e+04   4258.850      5.235      0.000    1.39e+04    3.06e+04
# C(CARGO)[T.1023-DIRETOR DE DESENVOLVIMENTO TECNOLOGICO E INOVACAO]                               2.003e+04   4258.833      4.703      0.000    1.17e+04    2.84e+04
# C(CARGO)[T.1026-DIRETOR DE NOVOS NEGÓCIOS E RELAÇÕES INSTITUCIONAIS]                             1.927e+04   4258.881      4.524      0.000    1.09e+04    2.76e+04
# C(CARGO)[T.1027-DIRETOR INDUSTRIAL DA SAÚDE]                                                     1.896e+04   4258.927      4.453      0.000    1.06e+04    2.73e+04
# C(CARGO)[T.1028-PROCURADOR JURÍDICO]                                                             2.016e+04   4259.046      4.733      0.000    1.18e+04    2.85e+04
# C(CARGO)[T.1100-AUXILIAR TÉCNICO]                                                                2756.8226   3688.298      0.747      0.455   -4472.472    9986.117
# C(CARGO)[T.1110-AUXILIAR TÉCNICO]                                                                 761.8633   3059.711      0.249      0.803   -5235.361    6759.088
# C(CARGO)[T.1150-AUXILIAR ADMINISTRATIVO]                                                         1851.4915   3145.398      0.589      0.556   -4313.686    8016.669
# C(CARGO)[T.1211-AUXILIAR TECNICO]                                                                3716.7860   3366.980      1.104      0.270   -2882.706    1.03e+04
# C(CARGO)[T.1216-AUXILIAR TECNICO]                                                                2349.2342   4258.840      0.552      0.581   -5998.360    1.07e+04
# C(CARGO)[T.1218-AUXILIAR ADMINISTRATIVO]                                                         3445.4677   3688.271      0.934      0.350   -3783.775    1.07e+04
# C(CARGO)[T.1500-ASSISTENTE TÉCNICO]                                                              2714.4552   3089.747      0.879      0.380   -3341.642    8770.552
# C(CARGO)[T.1504-ASSISTENTE ADMINISTRATIVO]                                                       4293.3012   4258.850      1.008      0.313   -4054.312    1.26e+04
# C(CARGO)[T.1510-ASSISTENTE ADMINISTRATIVO]                                                       4535.4766   4258.956      1.065      0.287   -3812.345    1.29e+04
# C(CARGO)[T.1520-ASSISTENTE ADMINISTRATIVO]                                                       3675.6535   3117.268      1.179      0.238   -2434.387    9785.694
# C(CARGO)[T.1530-ASSISTENTE ADMINISTRATIVO]                                                       2830.2512   3219.517      0.879      0.379   -3480.204    9140.707
# C(CARGO)[T.1560-ASSISTENTE/MOTORISTA]                                                            2131.6666   4258.956      0.501      0.617   -6216.155    1.05e+04
# C(CARGO)[T.1642- ASSISTENTE ADMINISTRATIVO/180]                                                   513.4890   4259.048      0.121      0.904   -7834.513    8861.490
# C(CARGO)[T.1º SARGENTO]                                                                          1544.4996    625.269      2.470      0.014     318.932    2770.067
# C(CARGO)[T.1º TENENTE]                                                                           9259.0127    741.280     12.491      0.000    7806.058    1.07e+04
# C(CARGO)[T.2001-TÉCNICO EM DESENVOLVIMENTO TECNOLÓGICO]                                          3878.5771   3688.434      1.052      0.293   -3350.985    1.11e+04
# C(CARGO)[T.2010-TÉCNICO EM CONTABILIDADE]                                                        7051.6135   3688.398      1.912      0.056    -177.877    1.43e+04
# C(CARGO)[T.2020-TÉCNICO ADMINISTRATIVO]                                                          7239.5180   4259.102      1.700      0.089   -1108.588    1.56e+04
# C(CARGO)[T.2040-TÉCNICO DE MANUTENÇÃO]                                                           6144.0658   3367.027      1.825      0.068    -455.518    1.27e+04
# C(CARGO)[T.2041-TÉCNICO DE MANUTENÇÃO]                                                           3350.2302   4258.856      0.787      0.431   -4997.395    1.17e+04
# C(CARGO)[T.2050-TÉCNICO EM DESENVOLVIMENTO TECNOLÓGICO]                                          3453.4652   3688.285      0.936      0.349   -3775.804    1.07e+04
# C(CARGO)[T.2051-TÉCNICO EM DESENVOLVIMENTO TECNOLÓGICO]                                          6290.5978   3688.259      1.706      0.088    -938.620    1.35e+04
# C(CARGO)[T.2060-TÉCNICO EM DESENVOLVIMENTO TECNOLÓGICO]                                          4035.8454   3688.319      1.094      0.274   -3193.491    1.13e+04
# C(CARGO)[T.2070-TÉCNICO EM DESENVOLVIMENTO TECNOLÓGICO]                                          4660.5080   4259.102      1.094      0.274   -3687.598     1.3e+04
# C(CARGO)[T.2080-TÉCNICO ADMINISTRATIVO]                                                          7146.8175   4258.902      1.678      0.093   -1200.898    1.55e+04
# C(CARGO)[T.2100-TÉCNICO ADMINISTRATIVO]                                                          7341.5471   4258.835      1.724      0.085   -1006.036    1.57e+04
# C(CARGO)[T.2120-TÉCNICO DE TECNOLOGIA DA INFORM. E COMUN]                                        3020.4958   4258.840      0.709      0.478   -5327.098    1.14e+04
# C(CARGO)[T.2130-TÉCNICO EM DESENVOLVIMENTO TECNOLÓGICO]                                          4728.9289   3094.032      1.528      0.126   -1335.567    1.08e+04
# C(CARGO)[T.2140-TÉCNICO EM DESENVOLVIMENTO TECNOLÓGICO]                                          3730.8875   4258.902      0.876      0.381   -4616.828    1.21e+04
# C(CARGO)[T.2150-TÉCNICO EM AVALIAÇÃO DA CONFORMIDADE]                                            5974.4544   4258.837      1.403      0.161   -2373.133    1.43e+04
# C(CARGO)[T.2161-TÉCNICO EM AVALIAÇÃO DA CONFORMIDADE]                                            1417.6710   4258.914      0.333      0.739   -6930.068    9765.410
# C(CARGO)[T.2181-TÉCNICO EM DESENVOLVIMENTO TECNOLÓGICO]                                          6146.9138   4259.151      1.443      0.149   -2201.289    1.45e+04
# C(CARGO)[T.2190-TÉCNICO EM SEGURANÇA DE TRABALHO]                                                3984.7913   3688.261      1.080      0.280   -3244.431    1.12e+04
# C(CARGO)[T.2511-ANALISTA DE GESTAO]                                                              5517.6710   4258.914      1.296      0.195   -2830.068    1.39e+04
# C(CARGO)[T.2520-ANALISTA DE GESTAO]                                                              1.001e+04   3194.202      3.133      0.002    3745.013    1.63e+04
# C(CARGO)[T.2521-ANALISTA DE GESTAO]                                                              6254.1046   4259.059      1.468      0.142   -2093.918    1.46e+04
# C(CARGO)[T.2530-ANALISTA ADVOGADO]                                                               1.127e+04   4259.062      2.646      0.008    2923.433    1.96e+04
# C(CARGO)[T.2540-ANALISTA CONTÁBIL]                                                               9194.0281   3366.927      2.731      0.006    2594.640    1.58e+04
# C(CARGO)[T.2550-ANALISTA ASSISTENTE SOCIAL]                                                      8384.3209   4259.124      1.969      0.049      36.170    1.67e+04
# C(CARGO)[T.2570-ANALISTA DE BIOTECNOLOGIA INDUSTRIAL]                                            1.153e+04   3477.512      3.315      0.001    4710.983    1.83e+04
# C(CARGO)[T.2580-ANALISTA DE BIOTECNOLOGIA INDUSTRIAL]                                            1.442e+04   3366.974      4.284      0.000    7823.749     2.1e+04
# C(CARGO)[T.2581-ANALISTA DE BIOTECNOLOGIA INDUSTRIAL]                                            1.124e+04   3688.660      3.046      0.002    4006.562    1.85e+04
# C(CARGO)[T.2582-ANALISTA DE BIOTECNOLOGIA INDUSTRIAL]                                            8156.4653   4259.166      1.915      0.055    -191.767    1.65e+04
# C(CARGO)[T.2600-ANALISTA DE BIOTECNOLOGIA INDUSTRIAL]                                            9089.1997   4259.216      2.134      0.033     740.870    1.74e+04
# C(CARGO)[T.2612-ANALISTA DE BIOTECNOLOGIA INDUSTRIAL]                                            1.092e+04   4259.053      2.565      0.010    2575.358    1.93e+04
# C(CARGO)[T.2620-ANALISTA DE COMUNICACAO]                                                          1.14e+04   4259.007      2.676      0.007    3049.527    1.97e+04
# C(CARGO)[T.2642-ANALISTA DE COMUNICAÇÃO E MERCADO]                                               1.101e+04   4258.840      2.585      0.010    2659.892    1.94e+04
# C(CARGO)[T.2651-ANALISTA DE INFRAESTRUTURA]                                                      1.118e+04   3688.259      3.030      0.002    3947.040    1.84e+04
# C(CARGO)[T.2652-ANALISTA DE INFRAESTRUTURA]                                                      7651.7032   4258.872      1.797      0.072    -695.953     1.6e+04
# C(CARGO)[T.2692-ANALISTA EM SAÚDE OCUPACIONAL]                                                   8080.3338   4259.151      1.897      0.058    -267.869    1.64e+04
# C(CARGO)[T.2710-ANALISTA DE SISTEMAS DE GESTÃO]                                                  1.527e+04   4259.047      3.586      0.000    6924.372    2.36e+04
# C(CARGO)[T.2711-ANALISTA DE SISTEMAS DE GESTÃO]                                                  7439.4033   4259.046      1.747      0.081    -908.594    1.58e+04
# C(CARGO)[T.2720-ANALISTA DE SISTEMAS DE GESTÃO]                                                  1.005e+04   3477.517      2.889      0.004    3229.968    1.69e+04
# C(CARGO)[T.2730-ANALISTA DE SISTEMAS DE GESTÃO]                                                  1.219e+04   4259.113      2.861      0.004    3836.932    2.05e+04
# C(CARGO)[T.2731-ANALISTA DE SISTEMAS DE GESTÃO]                                                  1.067e+04   4258.856      2.506      0.012    2325.625     1.9e+04
# C(CARGO)[T.2733-ANALISTA DE SISTEMAS DE GESTÃO]                                                  7877.7463   4258.989      1.850      0.064    -470.140    1.62e+04
# C(CARGO)[T.2740-ANALISTA DE TECN. DA INFORMAÇÃO E COMUN.]                                        1.018e+04   3477.356      2.927      0.003    3362.325     1.7e+04
# C(CARGO)[T.2750-ANALISTA DE TECN. DA INFORMAÇÃO E COMUN.]                                        1.103e+04   4258.881      2.591      0.010    2686.771    1.94e+04
# C(CARGO)[T.2760-ANALISTA DE TECNOLOGIA E INOVAÇÃO]                                               7643.7549   3477.472      2.198      0.028     827.693    1.45e+04
# C(CARGO)[T.2790-ANALISTA DE TECNOLOGIA E INOVAÇÃO]                                               1.228e+04   4258.845      2.883      0.004    3928.640    2.06e+04
# C(CARGO)[T.2810-ANALISTA DE TECNOLOGIA E INOVAÇÃO]                                               9733.1220   3477.469      2.799      0.005    2917.065    1.65e+04
# C(CARGO)[T.2812-ANALISTA DE TECNOLOGIA E INOVAÇÃO]                                               1.047e+04   4258.850      2.459      0.014    2125.656    1.88e+04
# C(CARGO)[T.2814-ANALISTA DE TECNOLOGIA E INOVAÇÃO]                                               1.145e+04   4258.902      2.690      0.007    3106.932    1.98e+04
# C(CARGO)[T.2815-ANALISTA DE TECNOLOGIA E INOVAÇÃO]                                               1.163e+04   4258.881      2.732      0.006    3285.822       2e+04
# C(CARGO)[T.2832-ANALISTA EM AVALIAÇÃO DA CONFORMIDADE]                                           7801.6149   4258.972      1.832      0.067    -546.238    1.61e+04
# C(CARGO)[T.2840-ANALISTA EM AVALIAÇÃO DA CONFORMIDADE]                                           7030.9956   4258.837      1.651      0.099   -1316.592    1.54e+04
# C(CARGO)[T.2860-ANALISTA EM AVALIAÇÃO DA CONFORMIDADE]                                           1.462e+04   4258.856      3.434      0.001    6276.704     2.3e+04
# C(CARGO)[T.2870-ANALISTA EM AVALIAÇÃO DA CONFORMIDADE]                                           1.392e+04   4258.872      3.269      0.001    5572.911    2.23e+04
# C(CARGO)[T.2880-ANALISTA EM AVALIAÇÃO DA CONFORMIDADE]                                           1.165e+04   3688.324      3.158      0.002    4416.710    1.89e+04
# C(CARGO)[T.2890-ANALISTA EM AVALIAÇÃO DA CONFORMIDADE]                                           6290.8258   4259.107      1.477      0.140   -2057.291    1.46e+04
# C(CARGO)[T.2900-ANALISTA SECRETÁRIA EXECUTIVA]                                                   1.061e+04   3688.514      2.876      0.004    3378.208    1.78e+04
# C(CARGO)[T.2910-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         1.184e+04   3367.011      3.516      0.000    5239.164    1.84e+04
# C(CARGO)[T.2920-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         9962.0675   3688.509      2.701      0.007    2732.358    1.72e+04
# C(CARGO)[T.2930-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         9179.1451   3688.264      2.489      0.013    1949.916    1.64e+04
# C(CARGO)[T.2950-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         6692.9312   4258.850      1.572      0.116   -1654.682     1.5e+04
# C(CARGO)[T.2960-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         9159.6907   3477.354      2.634      0.008    2343.859     1.6e+04
# C(CARGO)[T.2970-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         8095.1203   3477.619      2.328      0.020    1278.769    1.49e+04
# C(CARGO)[T.2990-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                          1.03e+04   3134.437      3.287      0.001    4159.795    1.64e+04
# C(CARGO)[T.2º SARGENTO]                                                                           875.3437    640.485      1.367      0.172    -380.047    2130.735
# C(CARGO)[T.2º TENENTE]                                                                           5081.2490   1971.560      2.577      0.010    1216.868    8945.630
# C(CARGO)[T.3000-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         8012.8746   4258.881      1.881      0.060    -334.799    1.64e+04
# C(CARGO)[T.3000-ANALISTA DE GESTAO]                                                              1.631e+04   4259.087      3.830      0.000    7965.411    2.47e+04
# C(CARGO)[T.3005-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         1.588e+04   4258.845      3.729      0.000    7535.660    2.42e+04
# C(CARGO)[T.3014-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         1.921e+04   4259.118      4.510      0.000    1.09e+04    2.76e+04
# C(CARGO)[T.3018-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         2.047e+04   4259.071      4.806      0.000    1.21e+04    2.88e+04
# C(CARGO)[T.3019-ANALISTA DE GESTAO]                                                              2.186e+04   4259.118      5.133      0.000    1.35e+04    3.02e+04
# C(CARGO)[T.3020-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         6810.4312   4258.850      1.599      0.110   -1537.182    1.52e+04
# C(CARGO)[T.3021-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         1.879e+04   4258.837      4.413      0.000    1.04e+04    2.71e+04
# C(CARGO)[T.3025-ANALISTA DE COMUNICACAO]                                                         1.953e+04   4259.055      4.586      0.000    1.12e+04    2.79e+04
# C(CARGO)[T.3028-ANALISTA DE TECNOLOGIA E INOVAÇÃO]                                               1.895e+04   4258.840      4.449      0.000    1.06e+04    2.73e+04
# C(CARGO)[T.3030-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         1.031e+04   3477.366      2.966      0.003    3496.760    1.71e+04
# C(CARGO)[T.3032-ANALISTA DE GESTAO]                                                               1.93e+04   4259.071      4.532      0.000     1.1e+04    2.77e+04
# C(CARGO)[T.3051-ANALISTA DE DESENVOLVIMENTO TECNOLÓGICO]                                         1.541e+04   4259.234      3.618      0.000    7059.795    2.38e+04
# C(CARGO)[T.3091-ANALISTA DE GESTÃO]                                                              1.109e+04   4258.941      2.605      0.009    2745.130    1.94e+04
# C(CARGO)[T.3093-ANALISTA DE TECNOLOGIA E INOVAÇÃO]                                               1.696e+04   4258.914      3.981      0.000    8608.252    2.53e+04
# C(CARGO)[T.3500-TÉCNICO DE TECNOLOGIA DA INFORM. E COMUN]                                        8147.4768   4258.872      1.913      0.056    -200.179    1.65e+04
# C(CARGO)[T.3501-TÉCNICO ADMINISTRATIVO]                                                          1.191e+04   3477.449      3.426      0.001    5098.505    1.87e+04
# C(CARGO)[T.3502-TÉCNICO EM AVALIAÇÃO DA CONFORMIDADE]                                            9487.0012   4258.850      2.228      0.026    1139.388    1.78e+04
# C(CARGO)[T.3504-TÉCNICO EM DESENVOLVIMENTO TECNOLÓGICO]                                          1.266e+04   3477.469      3.640      0.000    5841.814    1.95e+04
# C(CARGO)[T.3508-TÉCNICO EM DESENVOLVIMENTO TECNOLÓGICO]                                          1.024e+04   4258.837      2.405      0.016    1893.648    1.86e+04
# C(CARGO)[T.3º SARGENTO]                                                                          -349.5976    558.502     -0.626      0.531   -1444.297     745.102
# C(CARGO)[T.ADMINISTRADOR]                                                                        1.386e+04   3098.785      4.474      0.000    7789.371    1.99e+04
# C(CARGO)[T.ADVOGADO]                                                                             1.442e+04   3053.152      4.724      0.000    8439.772    2.04e+04
# C(CARGO)[T.ADVOGADO I]                                                                           1.851e+04   3219.594      5.749      0.000    1.22e+04    2.48e+04
# C(CARGO)[T.ADVOGADO II]                                                                           1.37e+04   4259.057      3.217      0.001    5354.341    2.21e+04
# C(CARGO)[T.ADVOGADO SR]                                                                          1.729e+04   3688.325      4.688      0.000    1.01e+04    2.45e+04
# C(CARGO)[T.AGENTE ADMINIST. I]                                                                   5934.8092   3045.681      1.949      0.051     -34.917    1.19e+04
# C(CARGO)[T.AGENTE ADMINIST. II]                                                                  9206.9731   3145.451      2.927      0.003    3041.692    1.54e+04
# C(CARGO)[T.AGENTE ADMINIST. III]                                                                 9868.1022   3252.831      3.034      0.002    3492.350    1.62e+04
# C(CARGO)[T.AGENTE DE APOIO]                                                                     -3855.4377    629.953     -6.120      0.000   -5090.185   -2620.690
# C(CARGO)[T.AGENTE DE CONTROLE INTERNO]                                                           5469.2794   4259.113      1.284      0.199   -2878.848    1.38e+04
# C(CARGO)[T.AGENTE DE EXECUÇÃO]                                                                    623.3040    622.338      1.002      0.317    -596.518    1843.126
# C(CARGO)[T.AGENTE DE SEGURANÇA SOCIOEDUCATIVO]                                                   1368.1706    668.376      2.047      0.041      58.112    2678.229
# C(CARGO)[T.AGENTE EDUCACIONAL EM OUTRO LOCAL]                                                    1957.0466   1616.236      1.211      0.226   -1210.877    5124.970
# C(CARGO)[T.AGENTE EDUCACIONAL I]                                                                   30.3899   1112.761      0.027      0.978   -2150.691    2211.470
# C(CARGO)[T.AGENTE EDUCACIONAL II]                                                                3817.3611   1112.152      3.432      0.001    1637.473    5997.249
# C(CARGO)[T.AGENTE FAZENDÁRIO ESTADUAL A]                                                         3381.5717   1190.778      2.840      0.005    1047.572    5715.572
# C(CARGO)[T.AGENTE FAZENDÁRIO ESTADUAL B]                                                         4254.2093   1511.585      2.814      0.005    1291.407    7217.012
# C(CARGO)[T.AGENTE FAZENDÁRIO ESTADUAL C]                                                         7705.6963   1848.811      4.168      0.000    4081.912    1.13e+04
# C(CARGO)[T.AGENTE PROFISSIONAL]                                                                  1733.6332    623.745      2.779      0.005     511.054    2956.212
# C(CARGO)[T.AGENTE UNIVERSITÁRIO DE APOIO]                                                       -2738.9524   1099.132     -2.492      0.013   -4893.321    -584.584
# C(CARGO)[T.AGENTE UNIVERSITÁRIO DE EXECUÇÃO]                                                     -503.7876    839.049     -0.600      0.548   -2148.377    1140.802
# C(CARGO)[T.AGENTE UNIVERSITÁRIO PROFISSIONAL]                                                    3700.8956    957.428      3.865      0.000    1824.277    5577.514
# C(CARGO)[T.ANALISTA]                                                                             1.339e+04   3015.294      4.442      0.000    7484.099    1.93e+04
# C(CARGO)[T.ANALISTA ADMINIST. JR]                                                                1.642e+04   3366.931      4.878      0.000    9823.681     2.3e+04
# C(CARGO)[T.ANALISTA ADMINIST. PL]                                                                2.242e+04   4259.107      5.263      0.000    1.41e+04    3.08e+04
# C(CARGO)[T.ANALISTA ADMINISTRATIVO]                                                              5249.4790   3688.693      1.423      0.155   -1980.590    1.25e+04
# C(CARGO)[T.ANALISTA DE ATIVIDADES DE TRANSITO]                                                   3873.0584   1214.412      3.189      0.001    1492.735    6253.382
# C(CARGO)[T.ANALISTA DE DESENVOLVIMENTO MUNICIP]                                                  1.603e+04   3158.540      5.076      0.000    9841.072    2.22e+04
# C(CARGO)[T.ANALISTA DE FINANÇAS E INVESTIMENTOS]                                                 1.338e+04   3298.923      4.056      0.000    6912.690    1.98e+04
# C(CARGO)[T.ANALISTA DE MARKETING]                                                                1044.7649   4258.972      0.245      0.806   -7303.088    9392.618
# C(CARGO)[T.ANALISTA DE PROCESSOS]                                                                1.125e+04   3073.654      3.660      0.000    5224.481    1.73e+04
# C(CARGO)[T.ANALISTA DE RECURSOS HUMANOS]                                                         2646.4181   3688.586      0.717      0.473   -4583.442    9876.278
# C(CARGO)[T.ANALISTA DE SIST. I]                                                                  1.016e+04   3477.368      2.923      0.003    3346.940     1.7e+04
# C(CARGO)[T.ANALISTA DE SISTEMAS]                                                                 2.014e+04   3477.360      5.792      0.000    1.33e+04     2.7e+04
# C(CARGO)[T.ANALISTA DE TECNOL INFORMACAO]                                                        9644.3536   4259.088      2.264      0.024    1296.273     1.8e+04
# C(CARGO)[T.ANALISTA DE TECNOLOGIA DA INFORMACA]                                                  1.257e+04   3117.289      4.033      0.000    6462.034    1.87e+04
# C(CARGO)[T.ANALISTA DE TECNOLOGIA DA INFORMAÇÃO]                                                  1.17e+04   3477.354      3.364      0.001    4880.573    1.85e+04
# C(CARGO)[T.ANALISTA DES. SOC. I]                                                                 1.125e+04   3299.067      3.410      0.001    4782.316    1.77e+04
# C(CARGO)[T.ANALISTA IMOBILIARIO JR]                                                              2.006e+04   4259.047      4.710      0.000    1.17e+04    2.84e+04
# C(CARGO)[T.ANALISTA PREV SR]                                                                     1.464e+04   3367.058      4.347      0.000    8036.166    2.12e+04
# C(CARGO)[T.ANALISTA SISTEM SR]                                                                    1.71e+04   4259.131      4.014      0.000    8749.860    2.54e+04
# C(CARGO)[T.ARQUITETA]                                                                            2144.4216   2289.237      0.937      0.349   -2342.627    6631.470
# C(CARGO)[T.ARQUITETO]                                                                            7941.8403   3174.706      2.502      0.012    1719.217    1.42e+04
# C(CARGO)[T.ARQUITETO JR]                                                                         1.915e+04   3299.080      5.803      0.000    1.27e+04    2.56e+04
# C(CARGO)[T.ARQUITETO PL]                                                                         2.136e+04   4259.046      5.016      0.000     1.3e+04    2.97e+04
# C(CARGO)[T.ARQUIVISTA DE PARTITURA]                                                              1699.1266   4259.135      0.399      0.690   -6649.045       1e+04
# C(CARGO)[T.ASSESSOR DE APOIO INTEGRADO I]                                                        1.506e+04   4259.057      3.537      0.000    6716.451    2.34e+04
# C(CARGO)[T.ASSESSOR DE APOIO INTEGRADO II]                                                       1.387e+04   4258.872      3.257      0.001    5523.591    2.22e+04
# C(CARGO)[T.ASSESSOR DE APOIO INTEGRADO III]                                                      1.721e+04   4258.956      4.041      0.000    8861.712    2.56e+04
# C(CARGO)[T.ASSESSOR DE APOIO INTEGRADO IV]                                                       2.275e+04   4258.837      5.343      0.000    1.44e+04    3.11e+04
# C(CARGO)[T.ASSESSOR DE APOIO INTEGRADO V]                                                        1.893e+04   4259.533      4.443      0.000    1.06e+04    2.73e+04
# C(CARGO)[T.ASSESSOR DE APOIO INTEGRADO VI]                                                       2.445e+04   4259.026      5.741      0.000    1.61e+04    3.28e+04
# C(CARGO)[T.ASSESSOR DE COMUNICACAO SOCIAL]                                                        2.13e+04   4259.354      5.001      0.000     1.3e+04    2.97e+04
# C(CARGO)[T.ASSESSOR DE DIRETOR]                                                                  4701.2330   3688.507      1.275      0.202   -2528.473    1.19e+04
# C(CARGO)[T.ASSESSOR DE DIRETOR PRESIDENTE]                                                       5785.8278   4259.007      1.358      0.174   -2562.093    1.41e+04
# C(CARGO)[T.ASSESSOR DE GOVERNANCA E GESTAO EST]                                                  1.833e+04   4258.837      4.304      0.000    9980.448    2.67e+04
# C(CARGO)[T.ASSESSOR DE PROGRAMAS ESPECIAIS]                                                      2.036e+04   4259.275      4.780      0.000     1.2e+04    2.87e+04
# C(CARGO)[T.ASSESSOR DE RELACOES INSTITUCIONAIS]                                                  2.072e+04   4259.239      4.865      0.000    1.24e+04    2.91e+04
# C(CARGO)[T.ASSESSOR ESPECIAL DA PRESIDÊNCIA - FILIA/ESCRITÓRIO DE REPRESENT]                     9606.0628   4259.418      2.255      0.024    1257.336     1.8e+04
# C(CARGO)[T.ASSESSOR ESPECIAL DA SUPERINTENDENC]                                                  1.876e+04   4259.046      4.405      0.000    1.04e+04    2.71e+04
# C(CARGO)[T.ASSESSOR I]                                                                           2872.5471   3477.403      0.826      0.409   -3943.381    9688.475
# C(CARGO)[T.ASSESSOR II]                                                                          4688.9042   3477.378      1.348      0.178   -2126.975    1.15e+04
# C(CARGO)[T.ASSESSOR III]                                                                         7500.2727   4258.845      1.761      0.078    -847.330    1.58e+04
# C(CARGO)[T.ASSESSOR III DA DIRETORIA DE ADMINISTRAÇÃO E FINANÇAS]                                8616.3538   4259.151      2.023      0.043     268.151     1.7e+04
# C(CARGO)[T.ASSESSOR III DA DIRETORIA DE INTERNACIONALIZAÇÃO]                                     8987.4394   4259.113      2.110      0.035     639.312    1.73e+04
# C(CARGO)[T.ASSESSOR IV]                                                                          1.393e+04   3477.354      4.006      0.000    7115.593    2.07e+04
# C(CARGO)[T.ASSESSOR SEM VÍNCULO]                                                                 1.932e+04   3117.330      6.199      0.000    1.32e+04    2.54e+04
# C(CARGO)[T.ASSESSOR TECNICO]                                                                     1672.4349   3688.519      0.453      0.650   -5557.293    8902.163
# C(CARGO)[T.ASSESSOR TECNICO ESPECIAL]                                                            5039.2035   3688.514      1.366      0.172   -2190.514    1.23e+04
# C(CARGO)[T.ASSESSOR TECNICO OPERACIONAL]                                                         2.331e+04   4258.845      5.473      0.000     1.5e+04    3.17e+04
# C(CARGO)[T.ASSESSORA DA PRESIDÊNCIA]                                                             2.106e+04   4259.234      4.946      0.000    1.27e+04    2.94e+04
# C(CARGO)[T.ASSESSORA EXECUTIVA]                                                                  5657.2428   4259.418      1.328      0.184   -2691.484     1.4e+04
# C(CARGO)[T.ASSIST CONTÁBIL]                                                                      1.022e+04   3366.908      3.034      0.002    3617.034    1.68e+04
# C(CARGO)[T.ASSIST. ADMINISTRATIVO]                                                               7751.7006   3028.480      2.560      0.010    1815.691    1.37e+04
# C(CARGO)[T.ASSIST.LABORATORIO]                                                                   9526.2336   3688.333      2.583      0.010    2296.869    1.68e+04
# C(CARGO)[T.ASSISTENTE ADMINIST.]                                                                 7746.3558   3219.435      2.406      0.016    1436.062    1.41e+04
# C(CARGO)[T.ASSISTENTE ADMINISTRATIVO]                                                            8434.3006   3079.219      2.739      0.006    2398.839    1.45e+04
# C(CARGO)[T.ASSISTENTE ADMINISTRATIVO (SUPORTE TÉCNICO) C]                                        2493.5818   3367.334      0.741      0.459   -4106.603    9093.767
# C(CARGO)[T.ASSISTENTE ADMINISTRATIVO III]                                                        4344.1417   4259.071      1.020      0.308   -4003.905    1.27e+04
# C(CARGO)[T.ASSISTENTE ADMINISTRATIVO IV]                                                         1741.1744   4258.837      0.409      0.683   -6606.413    1.01e+04
# C(CARGO)[T.ASSISTENTE DE FISCAL DA DEFESA AGROPECUÁRIA]                                           155.4287   1270.579      0.122      0.903   -2334.985    2645.843
# C(CARGO)[T.ASSISTENTE IMOBILIARIO]                                                                1.09e+04   3688.319      2.954      0.003    3667.600    1.81e+04
# C(CARGO)[T.ASSISTENTE SOC. II]                                                                   1.702e+04   3688.508      4.613      0.000    9785.527    2.42e+04
# C(CARGO)[T.ASSISTENTE SOCIAL]                                                                    1.027e+04   3174.664      3.235      0.001    4047.230    1.65e+04
# C(CARGO)[T.ASSISTENTE TECNICO]                                                                   1.327e+04   3688.285      3.597      0.000    6037.846    2.05e+04
# C(CARGO)[T.ASSISTENTE TECNICO I]                                                                 6548.8963   3219.487      2.034      0.042     238.500    1.29e+04
# C(CARGO)[T.ASSISTENTE TECNICO II]                                                                5662.7879   3252.841      1.741      0.082    -712.985     1.2e+04
# C(CARGO)[T.ASSISTENTE TECNICO III]                                                               1.436e+04   3252.903      4.414      0.000    7981.042    2.07e+04
# C(CARGO)[T.ATUARIO]                                                                              2.088e+04   4258.833      4.903      0.000    1.25e+04    2.92e+04
# C(CARGO)[T.AUDITOR]                                                                              1.302e+04   4258.881      3.058      0.002    4675.732    2.14e+04
# C(CARGO)[T.AUDITOR FISCAL]                                                                       1803.8535   2244.343      0.804      0.422   -2595.199    6202.906
# C(CARGO)[T.AUDITOR SENIOR]                                                                       1.933e+04   4258.872      4.538      0.000     1.1e+04    2.77e+04
# C(CARGO)[T.AUX MANUT/SERV GERAIS]                                                                2388.3436   3477.349      0.687      0.492   -4427.478    9204.165
# C(CARGO)[T.AUX. DE ESCRITORIO I]                                                                 7408.5724   4259.405      1.739      0.082    -940.128    1.58e+04
# C(CARGO)[T.AUX. DE ESCRITORIO II]                                                                5374.1311   3477.363      1.545      0.122   -1441.719    1.22e+04
# C(CARGO)[T.AUX.LIMPEZA]                                                                          3579.3214   3158.515      1.133      0.257   -2611.565    9770.208
# C(CARGO)[T.AUXILIAR ADMINIST.]                                                                   8134.3086   3299.180      2.466      0.014    1667.710    1.46e+04
# C(CARGO)[T.AUXILIAR ADMINISTRATIVO]                                                              1081.4151   4259.111      0.254      0.800   -7266.710    9429.540
# C(CARGO)[T.AUXILIAR DE ATIVIDADES DE TRANSITO]                                                   1267.9870   1428.942      0.887      0.375   -1532.830    4068.803
# C(CARGO)[T.AUXILIAR DE REGULACAO]                                                                 -85.4620   1393.457     -0.061      0.951   -2816.726    2645.802
# C(CARGO)[T.AUXILIAR TECNICO II]                                                                  1714.5895   4258.927      0.403      0.687   -6633.175    1.01e+04
# C(CARGO)[T.BAILARINO(A)]                                                                         4401.6052   3076.632      1.431      0.153   -1628.786    1.04e+04
# C(CARGO)[T.BIBLIOTECARIO]                                                                        1.879e+04   4259.190      4.412      0.000    1.04e+04    2.71e+04
# C(CARGO)[T.BIBLIOTECÁRIO]                                                                        6611.7041   4259.275      1.552      0.121   -1736.741     1.5e+04
# C(CARGO)[T.CABO]                                                                                -1926.3533    544.321     -3.539      0.000   -2993.256    -859.450
# C(CARGO)[T.CAPATAZ]                                                                              2874.1357   3117.159      0.922      0.357   -3235.692    8983.963
# C(CARGO)[T.CARGO COMISSIONADO EXECUTIVO]                                                         3991.6698   1664.575      2.398      0.016     728.998    7254.342
# C(CARGO)[T.CARGO EM COMISSÃO]                                                                    6362.0061   1679.812      3.787      0.000    3069.470    9654.542
# C(CARGO)[T.CARGO EM COMISSÃO -  ]                                                                5134.1807   3158.555      1.625      0.104   -1056.784    1.13e+04
# C(CARGO)[T.CC-ASSES.ESTRAT. I]                                                                   3361.3625   3299.107      1.019      0.308   -3105.094    9827.819
# C(CARGO)[T.CC-ASSES.ESTRAT. II]                                                                  4380.3334   3194.443      1.371      0.170   -1880.975    1.06e+04
# C(CARGO)[T.CC-ASSES.ESTRAT. III]                                                                 6155.4908   3252.813      1.892      0.058    -220.227    1.25e+04
# C(CARGO)[T.CC-ASSES.ESTRAT. IV]                                                                  1.451e+04   3477.512      4.172      0.000    7691.146    2.13e+04
# C(CARGO)[T.CLASSIFICADOR DE PRODUTOS]                                                            1.289e+04   3054.222      4.222      0.000    6908.232    1.89e+04
# C(CARGO)[T.COMUNIC.SOCIAL/JORNALISTA]                                                            1.874e+04   3688.281      5.080      0.000    1.15e+04     2.6e+04
# C(CARGO)[T.COMUNICADOR SOCIAL]                                                                   1.473e+04   4259.047      3.459      0.001    6381.945    2.31e+04
# C(CARGO)[T.CONSELHEIRO]                                                                          4482.1443   3838.458      1.168      0.243   -3041.474     1.2e+04
# C(CARGO)[T.CONSELHEIRO ADMINIST]                                                                 3692.7507   3897.040      0.948      0.343   -3945.693    1.13e+04
# C(CARGO)[T.CONSELHEIRO ADMINISTRATIVO]                                                           4832.8947   3590.425      1.346      0.178   -2204.563    1.19e+04
# C(CARGO)[T.CONSELHEIRO FISCAL]                                                                   2434.4354   3603.434      0.676      0.499   -4628.521    9497.391
# C(CARGO)[T.CONSELHO ADMINISTRATIVO]                                                              3068.8466   3298.919      0.930      0.352   -3397.241    9534.934
# C(CARGO)[T.CONSELHO FISCAL]                                                                       927.0501   3477.326      0.267      0.790   -5888.726    7742.826
# C(CARGO)[T.CONSULTOR TÉCNICO DE DESENVOLVIMENTO ECONÔMICO]                                       6907.4152   3477.619      1.986      0.047      91.065    1.37e+04
# C(CARGO)[T.CONSULTOR TÉCNICO DE GESTÃO]                                                          6003.8204   3367.129      1.783      0.075    -595.964    1.26e+04
# C(CARGO)[T.CONSULTOR TÉCNICO DE MERCADO]                                                         6319.1660   3688.637      1.713      0.087    -910.794    1.35e+04
# C(CARGO)[T.CONSUTOR TÉCNICO DE INTERNACIONALIZAÇÃO]                                              6535.1199   4259.366      1.534      0.125   -1813.505    1.49e+04
# C(CARGO)[T.CONTADOR]                                                                             1.176e+04   3145.498      3.738      0.000    5591.996    1.79e+04
# C(CARGO)[T.CONTROLADOR GERAL]                                                                    2.511e+04   4259.392      5.896      0.000    1.68e+04    3.35e+04
# C(CARGO)[T.CONTROLE INTERNO]                                                                     1758.8042   4258.840      0.413      0.680   -6588.790    1.01e+04
# C(CARGO)[T.COORDENADOR ADMINISTRATIVO]                                                           2.308e+04   4258.835      5.419      0.000    1.47e+04    3.14e+04
# C(CARGO)[T.COORDENADOR DE LICITAÇÕES E CONTRAT]                                                  2.148e+04   4258.833      5.044      0.000    1.31e+04    2.98e+04
# C(CARGO)[T.COORDENADOR DE RECURSOS HUMANOS]                                                      2.262e+04   4258.840      5.312      0.000    1.43e+04     3.1e+04
# C(CARGO)[T.COORDENADOR DE TECNOLOGIA DA INFORM]                                                  2.087e+04   4258.872      4.901      0.000    1.25e+04    2.92e+04
# C(CARGO)[T.DESENHISTA PROJ. II]                                                                  1.399e+04   3299.056      4.240      0.000    7523.194    2.05e+04
# C(CARGO)[T.DESENHISTA PROJETISTA]                                                                8764.7702   4259.079      2.058      0.040     416.709    1.71e+04
# C(CARGO)[T.DESENHISTA TECNICO]                                                                   5945.2822   4259.007      1.396      0.163   -2402.639    1.43e+04
# C(CARGO)[T.DESIGNER GRAFICO]                                                                      383.5911   3688.325      0.104      0.917   -6845.757    7612.940
# C(CARGO)[T.DESIGNER GRÁFICO]                                                                     3251.0229   3688.442      0.881      0.378   -3978.555    1.05e+04
# C(CARGO)[T.DIRETOR ADMINISTRATIVO E FINANCEIRO]                                                  1.456e+04   3688.426      3.947      0.000    7327.310    2.18e+04
# C(CARGO)[T.DIRETOR ADMINISTRATIVO FINANCEIRO]                                                    1.976e+04   4259.216      4.639      0.000    1.14e+04    2.81e+04
# C(CARGO)[T.DIRETOR DE OPERACOES MUNICIPAIS]                                                      1.497e+04   4258.902      3.515      0.000    6622.292    2.33e+04
# C(CARGO)[T.DIRETOR DE RELAÇÕES INSTITUCIONAIS]                                                   1.557e+04   4258.850      3.655      0.000    7217.648    2.39e+04
# C(CARGO)[T.DIRETOR PRESIDENTE]                                                                   2.108e+04   3688.487      5.716      0.000    1.39e+04    2.83e+04
# C(CARGO)[T.DIRETORA ARTÍSTICA]                                                                   7894.9175   4259.051      1.854      0.064    -453.089    1.62e+04
# C(CARGO)[T.DIRETORA DE CENA]                                                                       36.7953   4259.166      0.009      0.993   -8311.437    8385.027
# C(CARGO)[T.DOCENTE POR PRAZO DETERMINADO]                                                        1020.5167    639.935      1.595      0.111    -233.796    2274.829
# C(CARGO)[T.DOCENTES IEES]                                                                        3646.7311    715.700      5.095      0.000    2243.915    5049.548
# C(CARGO)[T.ECONOMIA DOMESTICA]                                                                   1.678e+04   4259.087      3.941      0.000    8436.191    2.51e+04
# C(CARGO)[T.ECONOMISTA]                                                                           1.451e+04   3688.271      3.935      0.000    7283.690    2.17e+04
# C(CARGO)[T.EDITOR DE IMAGEM E FINALIZAÇÃO]                                                        -87.7659   3477.364     -0.025      0.980   -6903.617    6728.085
# C(CARGO)[T.EDITOR DE RÁDIO E TV]                                                                 3647.4149   3477.488      1.049      0.294   -3168.680    1.05e+04
# C(CARGO)[T.ELETRICISTA]                                                                          5844.6715   4258.833      1.372      0.170   -2502.908    1.42e+04
# C(CARGO)[T.ELETROTÉCNICO]                                                                        1807.4205   4258.927      0.424      0.671   -6540.344    1.02e+04
# C(CARGO)[T.ENGENHEIRO]                                                                           1.577e+04   3688.322      4.275      0.000    8536.427     2.3e+04
# C(CARGO)[T.ENGENHEIRO AGRONOMO]                                                                  1.931e+04   3023.697      6.387      0.000    1.34e+04    2.52e+04
# C(CARGO)[T.ENGENHEIRO AMBIENTAL]                                                                 1.501e+04   3688.598      4.070      0.000    7781.510    2.22e+04
# C(CARGO)[T.ENGENHEIRO CARTOGRAFO]                                                                1.277e+04   3688.507      3.461      0.001    5536.897       2e+04
# C(CARGO)[T.ENGENHEIRO CIVIL]                                                                     1.105e+04   3039.893      3.635      0.000    5092.935     1.7e+04
# C(CARGO)[T.ENGENHEIRO ELETRICISTA]                                                               8882.8049   3299.184      2.692      0.007    2416.198    1.53e+04
# C(CARGO)[T.ENGENHEIRO FLORESTAL]                                                                 2.093e+04   3688.303      5.675      0.000    1.37e+04    2.82e+04
# C(CARGO)[T.ENGENHEIRO I]                                                                         1.967e+04   3219.659      6.109      0.000    1.34e+04     2.6e+04
# C(CARGO)[T.ENGENHEIRO II]                                                                         1.98e+04   3688.533      5.368      0.000    1.26e+04     2.7e+04
# C(CARGO)[T.ENGENHEIRO JR]                                                                         1.72e+04   3477.466      4.945      0.000    1.04e+04     2.4e+04
# C(CARGO)[T.ENGENHEIRO MECANICO]                                                                   1.71e+04   3688.259      4.637      0.000    9871.430    2.43e+04
# C(CARGO)[T.ENGENHEIRO PL]                                                                        1.984e+04   3688.285      5.379      0.000    1.26e+04    2.71e+04
# C(CARGO)[T.ENSAIADOR]                                                                            5111.3926   4259.254      1.200      0.230   -3237.012    1.35e+04
# C(CARGO)[T.ESPECIALISTA EM REGULACAO]                                                            6448.0977   1246.651      5.172      0.000    4004.584    8891.611
# C(CARGO)[T.FISCAL DA DEFESA AGROPECUÁRIA]                                                        8218.0174   1178.894      6.971      0.000    5907.312    1.05e+04
# C(CARGO)[T.FISIOTERAPEUTA]                                                                       9380.4344   3477.763      2.697      0.007    2563.801    1.62e+04
# C(CARGO)[T.FUNÇÃO COMISSIONADA EXECUTIVA]                                                        2543.4167   1664.987      1.528      0.127    -720.063    5806.896
# C(CARGO)[T.FUNÇÃO DE GESTÃO TRIBUTÁRIA]                                                          2001.5899   1669.359      1.199      0.231   -1270.458    5273.638
# C(CARGO)[T.FUNÇÃO PRIVATIVA SOCIOEDUCATIVA - FPS]                                                2184.0879   1738.368      1.256      0.209   -1223.222    5591.397
# C(CARGO)[T.GERENTE DE DESENVOLVIMENTO ECONÔMICO]                                                 1.783e+04   3688.487      4.835      0.000    1.06e+04    2.51e+04
# C(CARGO)[T.GERENTE DE INTERNACIONALIZAÇÃO]                                                       2.142e+04   4259.198      5.029      0.000    1.31e+04    2.98e+04
# C(CARGO)[T.GERENTE DE MERCADO]                                                                   1.964e+04   4258.837      4.612      0.000    1.13e+04     2.8e+04
# ...
# C(CARGO)[T.PERITO OFICIAL CRIMINAL 40 HORAS]                                                     1.137e+04    916.995     12.395      0.000    9568.726    1.32e+04
# C(CARGO)[T.POLICIAL PENAL]                                                                       5366.7920   1665.191      3.223      0.001    2102.913    8630.671
# C(CARGO)[T.PROCURADOR]                                                                           9950.2924   4259.137      2.336      0.019    1602.116    1.83e+04
# C(CARGO)[T.PROCURADOR JURIDICO]                                                                  1.929e+04   4259.137      4.529      0.000    1.09e+04    2.76e+04
# C(CARGO)[T.PROCURADOR JURÍDICO]                                                                   2.01e+04   4258.872      4.719      0.000    1.18e+04    2.84e+04
# C(CARGO)[T.PRODUTOR DE RADIO E TV]                                                               4203.7162   3298.981      1.274      0.203   -2262.493    1.07e+04
# C(CARGO)[T.PRODUTORA DE RADIO E TV]                                                              2766.7321   3688.529      0.750      0.453   -4463.016    9996.480
# C(CARGO)[T.PROF.DE NIVEL SUPERIOR III]                                                           1.426e+04   3174.476      4.493      0.000    8039.215    2.05e+04
# C(CARGO)[T.PROF.NIVEL SUPERIOR III]                                                              1.294e+04   4258.914      3.039      0.002    4596.342    2.13e+04
# C(CARGO)[T.PROFESSOR]                                                                            3372.2493   1664.404      2.026      0.043     109.913    6634.586
# C(CARGO)[T.PROFESSOR DE DANÇA]                                                                   2200.1684   3477.881      0.633      0.527   -4616.696    9017.033
# C(CARGO)[T.PROFESSOR DE DANÇA CLÁSSICA]                                                          4197.8150   4259.083      0.986      0.324   -4150.254    1.25e+04
# C(CARGO)[T.PROFESSOR EM OUTRO LOCAL]                                                             1609.0312   1310.022      1.228      0.219    -958.695    4176.757
# C(CARGO)[T.PROFESSOR ENQUADRADO]                                                                 2857.9978   1877.600      1.522      0.128    -822.216    6538.211
# C(CARGO)[T.PROFESSOR ENSINO SUPERIOR]                                                            8177.2712    745.540     10.968      0.000    6715.966    9638.576
# C(CARGO)[T.PROFISSIONAL AUXILIAR]                                                               -4423.6775   2557.728     -1.730      0.084   -9436.985     589.629
# C(CARGO)[T.PROFISSIONAL DE NÍVEL MÉDIO]                                                          1146.6824    896.960      1.278      0.201    -611.415    2904.779
# C(CARGO)[T.PROFISSIONAL DE NÍVEL SUPERIOR]                                                       5186.4309    703.607      7.371      0.000    3807.317    6565.545
# C(CARGO)[T.PROFISSIONAL ESPECIALISTA]                                                            2551.9865   1568.728      1.627      0.104    -522.818    5626.791
# C(CARGO)[T.PROFISSIONAL GRADUAÇÃO SUPERIOR]                                                      3296.8773   1200.686      2.746      0.006     943.457    5650.297
# C(CARGO)[T.PROFISSIONAL PESQUISADOR]                                                             9094.1163   1954.832      4.652      0.000    5262.524    1.29e+04
# C(CARGO)[T.PROGRAMADOR]                                                                          1.304e+04   3688.325      3.537      0.000    5815.321    2.03e+04
# C(CARGO)[T.PROGRAMADOR MUSICAL]                                                                   272.2388   4258.850      0.064      0.949   -8075.374    8619.852
# C(CARGO)[T.PROMOTOR DE SAUDE EXECUCAO]                                                           1744.2809    839.444      2.078      0.038      98.918    3389.643
# C(CARGO)[T.PROMOTOR DE SAUDE FUNDAMENTAL]                                                       -1192.6752    852.489     -1.399      0.162   -2863.607     478.257
# C(CARGO)[T.PROMOTOR DE SAUDE PROFISSIONAL]                                                       6483.7845    839.707      7.721      0.000    4837.907    8129.662
# C(CARGO)[T.PSICÓLOGO]                                                                            7449.6390   4258.914      1.749      0.080    -898.100    1.58e+04
# C(CARGO)[T.REDATOR PUBLICITÁRIO]                                                                  696.9261   4258.891      0.164      0.870   -7650.767    9044.620
# C(CARGO)[T.REPORTER DE RADIO E TV]                                                               4715.0929   3688.442      1.278      0.201   -2514.485    1.19e+04
# C(CARGO)[T.REPORTER FOTOGRAFICO]                                                                 2069.5073   4258.845      0.486      0.627   -6278.095    1.04e+04
# C(CARGO)[T.REPÓRTER CINEMATOGRÁFICO]                                                             3363.8096   3477.468      0.967      0.333   -3452.245    1.02e+04
# C(CARGO)[T.REPÓRTER DE RADIO E TV]                                                               3038.7830   3477.514      0.874      0.382   -3777.363    9854.929
# C(CARGO)[T.REPÓRTER FOTOGRÁFICO]                                                                 4181.3222   4259.067      0.982      0.326   -4166.715    1.25e+04
# C(CARGO)[T.SECRETARIA]                                                                           1883.5851   4259.111      0.442      0.658   -6464.540    1.02e+04
# C(CARGO)[T.SECRETARIA DO CONSELHO]                                                               1.098e+04   4259.049      2.578      0.010    2632.522    1.93e+04
# C(CARGO)[T.SECRETÁRIA EXECUTIVA]                                                                 2377.0221   4259.068      0.558      0.577   -5971.018    1.07e+04
# C(CARGO)[T.SERVENTE DE LIMPEZA]                                                                  -858.2037   4259.049     -0.202      0.840   -9206.208    7489.800
# C(CARGO)[T.SOCIOLOGO]                                                                            2.127e+04   4259.174      4.995      0.000    1.29e+04    2.96e+04
# C(CARGO)[T.SOLDADO 1ª CLASSE]                                                                   -2293.8631    578.630     -3.964      0.000   -3428.015   -1159.711
# C(CARGO)[T.SOLDADO 2ª CLASSE]                                                                   -6947.5111   2741.222     -2.534      0.011   -1.23e+04   -1574.545
# C(CARGO)[T.SONOPLASTA]                                                                            232.5910   3688.289      0.063      0.950   -6996.686    7461.868
# C(CARGO)[T.SUBTENENTE]                                                                           5001.1814    702.262      7.122      0.000    3624.704    6377.659
# C(CARGO)[T.SUPERVISOR DE OPERAÇÕES]                                                              1087.4010   4258.914      0.255      0.798   -7260.338    9435.140
# C(CARGO)[T.SUPERVISOR DE SUPRIMENTOS]                                                            4576.0878   4259.007      1.074      0.283   -3771.833    1.29e+04
# C(CARGO)[T.SUPERVISOR DE TRAF. MOV. II]                                                           940.6468   4258.872      0.221      0.825   -7407.009    9288.303
# C(CARGO)[T.SUPERVISOR MODULO]                                                                    1.033e+04   3688.313      2.802      0.005    3103.771    1.76e+04
# C(CARGO)[T.TEC. DE CONTABILIDADE]                                                                1.806e+04   3688.356      4.896      0.000    1.08e+04    2.53e+04
# C(CARGO)[T.TEC. EDIFICACOES II]                                                                  7120.3258   4258.840      1.672      0.095   -1227.268    1.55e+04
# C(CARGO)[T.TEC. INFORMATICA I]                                                                   1.005e+04   3366.980      2.984      0.003    3448.298    1.66e+04
# C(CARGO)[T.TEC. INFORMATICA II]                                                                  1.166e+04   4258.833      2.739      0.006    3316.062       2e+04
# C(CARGO)[T.TECNICO - NIV SUPERIOR]                                                               1.921e+04   3298.894      5.824      0.000    1.27e+04    2.57e+04
# C(CARGO)[T.TECNICO - NIVEL MEDIO]                                                                1.183e+04   3174.406      3.725      0.000    5604.030     1.8e+04
# C(CARGO)[T.TECNICO ADMINISTRATIVO]                                                               7395.8968   3023.753      2.446      0.014    1469.151    1.33e+04
# C(CARGO)[T.TECNICO AGRICOLA]                                                                      1.15e+04   3021.415      3.805      0.000    5573.994    1.74e+04
# C(CARGO)[T.TECNICO CONTABIL]                                                                     9715.8300   4258.833      2.281      0.023    1368.251    1.81e+04
# C(CARGO)[T.TECNICO DE ATIVIDADES DE TRANSITO]                                                    2547.0285    965.036      2.639      0.008     655.497    4438.560
# C(CARGO)[T.TECNICO DESENV. SOCIAL JR]                                                             1.04e+04   3477.517      2.990      0.003    3580.241    1.72e+04
# C(CARGO)[T.TECNICO IMOBILIARIO]                                                                  1.829e+04   3688.274      4.958      0.000    1.11e+04    2.55e+04
# C(CARGO)[T.TECNOLOGO EM GESTAO DE RECURSOS HUM]                                                  8174.6327   3688.511      2.216      0.027     944.920    1.54e+04
# C(CARGO)[T.TOPOGRAFO - PCS]                                                                        -2.5002   4258.856     -0.001      1.000   -8350.126    8345.125
# C(CARGO)[T.TRATORISTA]                                                                           3256.5444   3219.423      1.012      0.312   -3053.727    9566.816
# C(CARGO)[T.TÉCNICO]                                                                              5967.4526   3014.948      1.979      0.048      57.965    1.19e+04
# C(CARGO)[T.TÉCNICO DE INFORMÁTICA]                                                               7204.1007   4259.046      1.691      0.091   -1143.896    1.56e+04
# C(CARGO)[T.TÉCNICO DE PERÍCIA OFICIAL]                                                          -4041.2621    893.128     -4.525      0.000   -5791.850   -2290.674
# C(CARGO)[T.VIGIA FLORESTAL]                                                                      -965.3919   3688.383     -0.262      0.794   -8194.854    6264.070
# C(CARGO)[T.ZELADOR]                                                                               623.3702   4259.079      0.146      0.884   -7724.691    8971.431
# C(CARGO)[T.ZOOTECNISTA]                                                                          2.026e+04   3194.158      6.343      0.000     1.4e+04    2.65e+04
# C(REGIME)[T.ESTATUTÁRIO]                                                                        -2337.2094   1417.359     -1.649      0.099   -5115.322     440.904
# C(REGIME)[T.OUTROS]                                                                             -2704.9772   2282.840     -1.185      0.236   -7179.487    1769.533
# C(REGIME)[T.TEMPORÁRIO]                                                                           891.4359   1285.717      0.693      0.488   -1628.649    3411.521
# C(QUADRO_FUNCIONAL_DESC)[T.AUDITOR FISCAL]                                                       1803.8535   2244.343      0.804      0.422   -2595.199    6202.906
# C(QUADRO_FUNCIONAL_DESC)[T.CARGO COMISSIONADO EXECUTIVO]                                         3991.6698   1664.575      2.398      0.016     728.998    7254.342
# C(QUADRO_FUNCIONAL_DESC)[T.CLT]                                                                  8506.4278   2289.169      3.716      0.000    4019.512     1.3e+04
# C(QUADRO_FUNCIONAL_DESC)[T.EDUCAÇÃO BÁSICA]                                                      3847.7510   2219.655      1.733      0.083    -502.912    8198.414
# C(QUADRO_FUNCIONAL_DESC)[T.FUNÇÃO COMISSIONADA EXECUTIVA]                                        2543.4167   1664.987      1.528      0.127    -720.063    5806.896
# C(QUADRO_FUNCIONAL_DESC)[T.FUNÇÃO PRIVATIVA SOCIOEDUCATIVA]                                      2184.0879   1738.368      1.256      0.209   -1223.222    5591.397
# C(QUADRO_FUNCIONAL_DESC)[T.GESTÃO TRIBUTÁRIA]                                                    2001.5899   1669.359      1.199      0.231   -1270.458    5273.638
# C(QUADRO_FUNCIONAL_DESC)[T.MAGISTÉRIO]                                                           3372.2493   1664.404      2.026      0.043     109.913    6634.586
# C(QUADRO_FUNCIONAL_DESC)[T.MAGISTÉRIO (EM EXTINÇÃO)]                                             2857.9978   1877.600      1.522      0.128    -822.216    6538.211
# C(QUADRO_FUNCIONAL_DESC)[T.MAGISTÉRIO SUPERIOR]                                                  8635.4268   2678.765      3.224      0.001    3384.879    1.39e+04
# C(QUADRO_FUNCIONAL_DESC)[T.PERITOS OFICIAIS]                                                     1.319e+04   2505.083      5.264      0.000    8276.424    1.81e+04
# C(QUADRO_FUNCIONAL_DESC)[T.QUADRO DO BOMBEIRO MILITAR]                                           1.024e+04   3020.470      3.392      0.001    4323.651    1.62e+04
# C(QUADRO_FUNCIONAL_DESC)[T.QUADRO DOS SERVIDORES DA AGEPAR]                                      6362.6357   2265.259      2.809      0.005    1922.585    1.08e+04
# C(QUADRO_FUNCIONAL_DESC)[T.QUADRO GERAL]                                                         9978.5952   2859.287      3.490      0.000    4374.214    1.56e+04
# C(QUADRO_FUNCIONAL_DESC)[T.QUADRO PRÓPRIO DA AGÊNCIA DE DEFESA AGROPECUÁRIA DO PARANÁ - ADAPAR]  8373.4462   2243.358      3.733      0.000    3976.324    1.28e+04
# C(QUADRO_FUNCIONAL_DESC)[T.QUADRO PRÓPRIO DA POLÍCIA PENAL]                                      5366.7920   1665.191      3.223      0.001    2102.913    8630.671
# C(QUADRO_FUNCIONAL_DESC)[T.QUADRO PRÓPRIO DO IDR]                                                1.052e+04   2783.458      3.779      0.000    5063.551     1.6e+04
# C(QUADRO_FUNCIONAL_DESC)[T.QUADRO PRÓPRIO FAZENDÁRIO]                                            1.534e+04   2586.529      5.931      0.000    1.03e+04    2.04e+04
# C(QUADRO_FUNCIONAL_DESC)[T.SAÚDE]                                                                7035.3901   2497.523      2.817      0.005    2140.089    1.19e+04
# C(QUADRO_FUNCIONAL_DESC)[T.SISTEMA DE PAGAMENTO DE SERVIÇOS EVENTUAIS]                           3566.0778   2301.683      1.549      0.121    -945.365    8077.520
# C(QUADRO_FUNCIONAL_DESC)[T.TEMPORÁRIOS]                                                           891.4359   1285.717      0.693      0.488   -1628.649    3411.521
# C(QUADRO_FUNCIONAL_DESC)[T.TRÂNSITO]                                                             7688.0739   2539.145      3.028      0.002    2711.190    1.27e+04
# IDADE                                                                                              76.1315      2.029     37.513      0.000      72.154      80.109
# ==============================================================================
# Omnibus:                     5547.975   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16383.837
# Skew:                           1.183   Prob(JB):                         0.00
# Kurtosis:                       6.241   Cond. No.                     8.26e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.9e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
novo_funcionario = pd.DataFrame({
    'IDADE': [30],
    'GENERO': ['M'],
    'CARGO': ['ANALISTA DE SISTEMAS'],
    'REGIME': ['ESTATUTÁRIO'],
    'QUADRO_FUNCIONAL_DESC': ['MAGISTÉRIO'],
})

response.predict(novo_funcionario)
# Out:
# 0    22639.520187
# dtype: float64

# %% [markdown]
# ## Clusterização
# Objetivo: encontrar grupos semelhantes utilizando idade, remuneração e município

# %%
# Importando as Bibliotecas
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
df_cluster = df_ativos_filtrado.copy()

df_cluster = df_cluster[(df_cluster['MUNICIPIO'] == 'CURITIBA') & (df_cluster['REGIME'] == 'CLT')]

df_cluster = df_cluster[['IDADE', 'ULTIMA_REMUNERACAO_BRUTA', 'ANO_NASCIMENTO', 'ANO_INICIO']]

# Normalização dos dados
df_cluster_norm = pd.DataFrame(
                  MinMaxScaler().fit_transform(df_cluster), 
                  index = df_cluster.index, 
                  columns=df_cluster.columns)

print("Dados normalizados:")
print(df_cluster_norm)
# Out:
# Dados normalizados:
#            IDADE  ULTIMA_REMUNERACAO_BRUTA  ANO_NASCIMENTO  ANO_INICIO
# 1562    0.384615                  0.452253        0.615385    0.872727
# 1563    0.323077                  0.060204        0.676923    0.690909
# 1598    0.384615                  0.310350        0.615385    0.654545
# 2024    0.600000                  0.178663        0.400000    0.654545
# 2258    0.461538                  0.151447        0.538462    0.727273
# ...          ...                       ...             ...         ...
# 869993  0.276923                  0.380555        0.723077    1.000000
# 870026  0.323077                  0.460801        0.676923    0.800000
# 870611  0.615385                  0.535554        0.384615    0.436364
# 870794  0.307692                  0.718049        0.692308    0.690909
# 871672  0.430769                  0.554320        0.569231    0.563636
#
# [2486 rows x 4 columns]

# %%
from math import sqrt

# Método do Cotovelo 
def calc_inertia(df):
    inertias = []
    for k in range(1, 11):
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        kmeans.fit(df_cluster_norm)
        inertias.append(kmeans.inertia_)

    return inertias

inertias = calc_inertia(df_cluster_norm)

# Função para obter o melhor valor de K com base no método do cotovelo
def k_optimal(inertias):
    x1, y1 = 2, inertias[0]
    x2, y2 = 20, inertias[len(inertias)-1]

    distances = []
    for i in range(len(inertias)):
        x0 = i+2
        y0 = inertias[i]
        numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
        denominator = sqrt((y2 - y1)**2 + (x2 - x1)**2)
        distances.append(numerator/denominator)
    
    return distances.index(max(distances)) + 2

optimal_k = k_optimal(inertias)

print(f"O número ótimo de clusters é: {optimal_k}")

# Plotando o gráfico de inércia
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), inertias, marker='o')
plt.title('Inércia do K-Means para diferentes valores de K')
plt.xlabel('Número de Clusters (K)')
plt.ylabel('Inércia')
plt.xticks(range(1, 11))
plt.grid(True)
plt.show()
# Out:
# O número ótimo de clusters é: 6

# %%
# Aplicando o KMeans
kmeans = KMeans(n_clusters = optimal_k, random_state = 42)  
kmeans.fit(df_cluster_norm) 
df_cluster['Agrupamento'] = kmeans.labels_

df_cluster['Agrupamento'].value_counts().sort_index()
# Out:
# Agrupamento
# 0    346
# 1    394
# 2    447
# 3    554
# 4    477
# 5    268
# Name: count, dtype: int64

# %%
# Gráfico de dispersão: Idade vs Remuneração colorido por cluster
colors = ['red', 'blue', 'green', 'orange', 'purple', 'black']

plt.figure(figsize=(12, 8))
for i in range(optimal_k):
    cluster_values = df_cluster[df_cluster['Agrupamento'] == i]
    plt.scatter(cluster_values['IDADE'], cluster_values['ULTIMA_REMUNERACAO_BRUTA'], c=colors[i], label=f'Cluster {i}', alpha=0.6)

plt.xlabel('Idade')
plt.ylabel('Última Remuneração Bruta')
plt.title('Clusters de Servidores (CLT) em Curitiba')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Gráfico de dispersão: Idade vs Remuneração colorido por cluster
colors = ['red', 'blue', 'green', 'orange', 'purple', 'black']

plt.figure(figsize=(12, 8))
for i in range(optimal_k):
    cluster_values = df_cluster[df_cluster['Agrupamento'] == i]
    plt.scatter(cluster_values['ANO_NASCIMENTO'], cluster_values['ULTIMA_REMUNERACAO_BRUTA'], c=colors[i], label=f'Cluster {i}', alpha=0.6)

plt.xlabel('Ano de Nascimento')
plt.ylabel('Última Remuneração Bruta')
plt.title('Clusters de Servidores (CLT) em Curitiba')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Gráfico de dispersão: Idade vs Remuneração colorido por cluster
colors = ['red', 'blue', 'green', 'orange', 'purple', 'black']

plt.figure(figsize=(12, 8))
for i in range(optimal_k):
    cluster_values = df_cluster[df_cluster['Agrupamento'] == i]
    plt.scatter(cluster_values['ANO_INICIO'], cluster_values['ULTIMA_REMUNERACAO_BRUTA'], c=colors[i], label=f'Cluster {i}', alpha=0.6)

plt.xlabel('Ano de Início')
plt.ylabel('Última Remuneração Bruta')
plt.title('Clusters de Servidores (CLT) em Curitiba')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
